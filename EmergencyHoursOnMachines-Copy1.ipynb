# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_master = pd.read_excel("master_file_final.xlsx")
df_appts = pd.read_excel("allapptslinac2010-2020.xlsx")

# %%
df_emergency = df_master[df_master['Category_x']=='Emergency 1']
df_emergency['Year'] = df_emergency['CreatedDate'].dt.year
df_emergency['Month'] = df_emergency['CreatedDate'].dt.month
# create YearMonth column
df_emergency['dateInt']= df_emergency['Year'].astype(str) + df_emergency['Month'].astype(str).str.zfill(2)
df_emergency['YearMonth'] = pd.to_datetime(df_emergency['dateInt'], format='%Y%m')
df_emergency
# Out:
# <ipython-input-4-f9398656aa62>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emergency['Year'] = df_emergency['CreatedDate'].dt.year
# <ipython-input-4-f9398656aa62>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emergency['Month'] = df_emergency['CreatedDate'].dt.month
# <ipython-input-4-f9398656aa62>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emergency['dateInt']= df_emergency['Year'].astype(str) + df_emergency['Month'].astype(str).str.zfill(2)
# <ipython-input-4-f9398656aa62>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_emergency['YearMonth'] = pd.to_datetime(df_emergency['dateInt'], format='%Y%m')
#            MRN CreatedDate         CreatedTime ActivatedDate  \
# 26       22300  2020-10-02 1999-11-30 11:40:22    2020-10-02
# 61       55835  2014-12-24 1999-11-30 13:20:48    2014-12-24
# 71       63082  2014-08-12 1999-11-30 14:23:42    2014-08-12
# 117      89025  2010-03-10 1999-11-30 22:16:33    2010-03-10
# 123      91224  2012-01-20 1999-11-30 13:51:32    2012-01-20
# ...        ...         ...                 ...           ...
# 57736  6273510  2014-03-19 1999-11-30 13:53:14    2014-03-19
# 57738  6282070  2015-02-14 1999-11-30 12:30:45    2015-02-14
# 57740  6289611  2016-03-18 1999-11-30 17:30:24    2016-03-18
# 57747  6327819  2011-04-08 1999-11-30 11:46:15    2011-04-08
# 57754  6351835  2012-03-17 1999-11-30 14:56:50    2012-03-17
#
#             ActivatedTime          SiteGroup                      Diagnosis  \
# 26    1999-11-30 11:43:55             BREAST       Mets to Bone - Ca Breast
# 61    1999-11-30 13:25:44               LUNG             ca lung NSCLC-left
# 71    1999-11-30 14:26:49  GENITOURINARY(GU)                    Ca Prostate
# 117   1999-11-30 22:20:52             BREAST          Mets Misc - Ca Breast
# 123   1999-11-30 13:56:56  ENT (HEAD & NECK)                    Oral Cavity
# ...                   ...                ...                            ...
# 57736 1999-11-30 13:58:14               LUNG              ca lung SCCL-left
# 57738 1999-11-30 12:33:40             BREAST  Ca Breast NOS (excludes Skin)
# 57740 1999-11-30 17:43:07               LUNG            mets bone - ca lung
# 57747 1999-11-30 11:54:22           GI UPPER                     Ca Stomach
# 57754 1999-11-30 14:59:20               SKIN                       Melanoma
#
#         Category_x PlanCreateDate      PlanCreateTime  ... Tx-TxBook  \
# 26     Emergency 1     2020-10-02 1999-11-30 11:42:21  ...         0
# 61     Emergency 1     2014-12-24 1999-11-30 13:24:43  ...         0
# 71     Emergency 1     2014-08-12 1999-11-30 14:25:45  ...         1
# 117    Emergency 1     2010-03-10 1999-11-30 22:19:07  ...        -1
# 123    Emergency 1     2012-01-20 1999-11-30 13:54:55  ...         1
# ...            ...            ...                 ...  ...       ...
# 57736  Emergency 1     2014-03-19 1999-11-30 13:57:53  ...         0
# 57738  Emergency 1     2015-02-14 1999-11-30 12:31:53  ...         0
# 57740  Emergency 1     2016-03-18 1999-11-30 17:38:18  ...         1
# 57747  Emergency 1     2011-04-08 1999-11-30 11:48:27  ...         0
# 57754  Emergency 1     2012-03-17 1999-11-30 14:58:09  ...         0
#
#       Tx-PlanCompl Tx-PlanPrompt Tx-PlanReview  PlanWait Unnamed: 86  Year  \
# 26             NaN           NaN           NaN       NaN         NaN  2020
# 61             NaN           NaN           NaN       NaN         NaN  2014
# 71             NaN           NaN           NaN       NaN         NaN  2014
# 117            NaN           NaN           NaN       NaN         NaN  2010
# 123            NaN           NaN           NaN       NaN         NaN  2012
# ...            ...           ...           ...       ...         ...   ...
# 57736          NaN           NaN           NaN       NaN         NaN  2014
# 57738          NaN           NaN           NaN       NaN         NaN  2015
# 57740          NaN           NaN           NaN       NaN         NaN  2016
# 57747          NaN           NaN           NaN       NaN         NaN  2011
# 57754          NaN           NaN           NaN       NaN         NaN  2012
#
#       Month dateInt  YearMonth
# 26       10  202010 2020-10-01
# 61       12  201412 2014-12-01
# 71        8  201408 2014-08-01
# 117       3  201003 2010-03-01
# 123       1  201201 2012-01-01
# ...     ...     ...        ...
# 57736     3  201403 2014-03-01
# 57738     2  201502 2015-02-01
# 57740     3  201603 2016-03-01
# 57747     4  201104 2011-04-01
# 57754     3  201203 2012-03-01
#
# [1819 rows x 92 columns]

# %%
### CTs mins booked on each CT
df_CTmins = df_emergency.groupby([df_emergency['SimLocation'],df_emergency['YearMonth']]
                                )['SimApptDuration'].agg('sum').reset_index()
                                                                                                            
CTs = df_CTmins['SimLocation'].unique()
for u in CTs:
    y = df_CTmins[df_CTmins['SimLocation']==u]['SimApptDuration']
    x = df_CTmins[df_CTmins['SimLocation']==u]['YearMonth']

    plt.plot(x, y)
    plt.xlabel('Year')
    plt.ylabel('Mins')
    plt.title('Emergency minutes '+u)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.show()

# %%
df_appts['Year'] = df_appts['ApptDate'].dt.year
df_appts['Month'] = df_appts['ApptDate'].dt.month
df_totalmins = df_appts.groupby([df_appts['MRN'],df_appts['TxUnit'],df_appts['Year'],df_appts['Month']]
                               )['Duration'].agg('sum').reset_index()
df_totalmins['Year']=df_totalmins['Year'].astype(int)
df_totalmins['Month']=df_totalmins['Month'].astype(int)
# create YearMonth column
df_totalmins['dateInt']= df_totalmins['Year'].astype(str) + df_totalmins['Month'].astype(str).str.zfill(2)
df_totalmins['YearMonth'] = pd.to_datetime(df_totalmins['dateInt'], format='%Y%m')
df_totalmins.head()
# Out:
#       MRN TxUnit  Year  Month  Duration dateInt  YearMonth
# 0    99.0   WV16  2019      8      30.0  201908 2019-08-01
# 1  2918.0   SA04  2015     12      15.0  201512 2015-12-01
# 2  2918.0   WA15  2015     12      15.0  201512 2015-12-01
# 3  5723.0   NA10  2013      8     285.0  201308 2013-08-01
# 4  5723.0   NA10  2013      9     270.0  201309 2013-09-01

# %%
df_EmergMins = df_totalmins.merge(df_emergency, on=['MRN','YearMonth'])

# %%
df_EmergMins[['MRN','Duration','TxUnit_x','YearMonth']]
# Out:
#             MRN  Duration TxUnit_x  YearMonth
# 0       22300.0      30.0     NA10 2020-10-01
# 1       22300.0      30.0     NA12 2020-10-01
# 2      141596.0      30.0     EA05 2016-09-01
# 3      141596.0      15.0     NA12 2016-09-01
# 4      198511.0      30.0     EA08 2019-02-01
# ...         ...       ...      ...        ...
# 1183  6353704.0      60.0     WA15 2019-06-01
# 1184  6354823.0      40.0     NA10 2020-03-01
# 1185  6354823.0      80.0     WA15 2020-03-01
# 1186  6387457.0      30.0     NA09 2017-05-01
# 1187  6387457.0      15.0     NA12 2017-05-01
#
# [1188 rows x 4 columns]

# %%
df_E1_mins_unit = df_EmergMins.groupby([df_EmergMins['TxUnit_x'],df_EmergMins['YearMonth']]
                                      )['Duration'].agg('sum').reset_index()
df_E1_mins_unit
# Out:
#     TxUnit_x  YearMonth  Duration
# 0       EA05 2013-12-01      15.0
# 1       EA05 2014-01-01      30.0
# 2       EA05 2014-07-01     105.0
# 3       EA05 2014-08-01      30.0
# 4       EA05 2014-11-01     110.0
# ..       ...        ...       ...
# 552     WV16 2018-12-01      30.0
# 553     WV16 2019-01-01      30.0
# 554     WV16 2019-06-01      30.0
# 555     WV16 2019-10-01      45.0
# 556     WV16 2020-01-01      50.0
#
# [557 rows x 3 columns]

# %%
df_recent = df_E1_mins_unit[(df_E1_mins_unit['YearMonth']>=pd.to_datetime('2019-10-01'))&(df_E1_mins_unit['YearMonth']<pd.to_datetime('2020-01-01'))]
df_recent.groupby(['TxUnit_x'])['Duration'].agg('mean')
# Out:
# TxUnit_x
# EA07     45.000000
# EA08     65.000000
# EV06     30.000000
# NA09     30.000000
# NA10     60.000000
# NA11    145.000000
# NA12    411.666667
# SA04     60.000000
# WA15    115.000000
# WA17     60.000000
# WV16     45.000000
# Name: Duration, dtype: float64

# %%
units = df_E1_mins_unit['TxUnit_x'].unique()
for u in units:
    y = df_E1_mins_unit[df_E1_mins_unit['TxUnit_x']==u]['Duration']
    x = df_E1_mins_unit[df_E1_mins_unit['TxUnit_x']==u]['YearMonth']

    plt.plot(x, y)
    plt.xlabel('Year')
    plt.ylabel('Mins')
    plt.title('Emergency minutes '+u)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

    plt.show()
